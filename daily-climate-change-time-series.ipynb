# %% [markdown]
# <h1 style="font-family:verdana; color:red"> <center>Prediction of daily climate using machine learning and deep learning.</center></h1>
#
# <p><center style="color:#159364; font-family:cursive; font-size:20px;">Thanks for visiting my notebook </center></p>
#
#
#
# <center><img src='https://media.giphy.com/media/fIXdXxDQDxYDSJ4dDA/giphy.gif'></center>

# %% [markdown]
# <div>
#  <p><center style="color:#159364; font-family:cursive; font-size:20px;">Things to do:</center></p>
# <p><center style="color:#159364; font-family:cursive; font-size:20px;">1.Data Preprocesssig</center></p>
# <p><center style="color:#159364; font-family:cursive; font-size:20px;">2.Exploratory Data Analysis</center></p>
# <p><center style="color:#159364; font-family:cursive; font-size:20px;">3.model building</center></p>
# <p><center style="color:#159364; font-family:cursive; font-size:20px;">4.Time Series forcasting</center></p>
# </div>

# %% [markdown]
# <center><h1 style='background-color:#99ccff;padding:10px;font-family:courier'>📗 importing the libraries</h1></center>

# %% [markdown]
# **What is pandas:Pandas is python built in library.It is used for the data manipulation and data handling.**
#
# **What is numpy: Numpy is python library usde for mathamatival operartions.**
#
# **What is matplotlib:Python library used for graphs and presentation.**

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load


import warnings 
warnings.filterwarnings("ignore")
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)


import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style('darkgrid')
sns.set_palette('Set2')

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
print("Module Loaded")

# %% [markdown]
# <center><h1 style='background-color:#99ccff;padding:10px;font-family:courier'>📄Import  datasets</h1></center>

# %%
data=pd.read_csv("/kaggle/input/daily-climate-time-series-data/DailyDelhiClimateTest.csv")

# %%
data.head()

# %% [markdown]
# <center><h1 style='background-color:#99ccff;padding:10px;font-family:courier'>📄 Data Processing And Cleaning</h1></center>

# %%
data.describe()

# %%
data.info()

# %%
data.isnull().sum()

# %%
data.shape

# %%
data.duplicated().sum()

# %%
data.head()

# %% [markdown]
# <center><h1 style='background-color:#99ccff;padding:10px;font-family:courier'>🔍EDA With Seaborn And Matplotlib</h1></center>

# %%
#data.iloc[:, 1:5]
plt.figure(figsize=(15,10))
i=1
for col in data.iloc[:,1:5]:
    plt.subplot(2,2,i)
    sns.histplot(data[col])
    i=i+1

# %%
data.index=pd.to_datetime(data.date)

# %%
data.head()

# %%
plt.figure(figsize=(15,5))
plt.plot(data['meantemp'],marker="o",label="mean temp")
plt.plot(data['humidity'],marker="o",label="Humidity")
plt.plot(data['wind_speed'],marker="o",label="Wind Speed")
plt.title("MEANTEMP VS HUMIDITY VS WIND SPEED")
plt.xlabel("count")
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# **Temperature is opposite to the humidity .If Humidity increase temperature decreses and vice versa**

# %%
data['date'] = pd.to_datetime(data['date'])


data['day'] = data['date'].dt.day
data['hour'] = data['date'].dt.hour
data['month'] = data['date'].dt.month

# %%
data.head()

# %%
data.groupby(by="day").mean()

# %%
plt.figure(figsize=(10,5))
plt.title("MEAN TEMPERATURE HIMIDITY AND WID SPEED IN DAY")
sns.lineplot(data.groupby(by="day")['meantemp'].mean())
sns.lineplot(data.groupby(by="day")['humidity'].mean())
sns.lineplot(data.groupby(by="day")['wind_speed'].mean())
plt.xticks(rotation=45)
plt.grid()
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.title("MEAN TEMPERATURE HIMIDITY AND WID SPEED IN MONTH")
sns.lineplot(data.groupby(by="month")['meantemp'].mean())
sns.lineplot(data.groupby(by="month")['humidity'].mean())
sns.lineplot(data.groupby(by="month")['wind_speed'].mean())
plt.xticks(rotation=45)
plt.grid()
plt.show()

# %%
tempdata=data[['meantemp']]

tempdata.index=pd.to_datetime(data.date)

# %%
plt.figure(figsize=(15,5))
plt.xlabel("Time Frame")
plt.ylabel("Avarage temp records")
plt.title("temprature trend in all over  dataset")
plt.plot(tempdata)
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.title("HEATMAP FOR DATASET")
sns.heatmap(data.iloc[:,1:5].corr(),annot=True);
plt.show();

# %% [markdown]
# <center><h1 style='background-color:#99ccff;padding:10px;font-family:courier'>Time Series</h1></center>

# %% [markdown]
# **Time series forecasting is the process of predicting future values or events based on historical data in a time-ordered sequence. It involves using past observations to make informed predictions about future data points. Time series forecasting is widely used in various fields, including finance, economics, sales, inventory management, weather forecasting, and more.**
#
# **The goal of time series forecasting is to identify underlying patterns, trends, and seasonal variations within the data to make accurate predictions. There are several methods and models used for time series forecasting, depending on the nature of the data and the specific problem at hand. Some of the commonly used techniques include:**
#
# **1.Autoregressive Integrated Moving Average (ARIMA): ARIMA is a popular method for forecasting stationary time series data. It involves identifying autoregressive (AR) and moving average (MA) components in the data and applying differencing to make it stationary.**
#
# **2.Seasonal Autoregressive Integrated Moving-Average (SARIMA): SARIMA is an extension of ARIMA that takes into account seasonal components in the data, making it suitable for forecasting data with seasonal patterns.**
#
# **3.Exponential Smoothing (ETS): ETS methods use weighted averages of past observations to forecast future values. It includes various models like Simple Exponential Smoothing, Double Exponential Smoothing, and Triple Exponential Smoothing (Holt-Winters method).**
#
# **4.Prophet: Prophet is a forecasting model developed by Facebook, designed to handle time series data with seasonality and holiday effects.**
#
# **5.Machine Learning Algorithms: Advanced machine learning algorithms like Random Forests, Gradient Boosting Machines, and Long Short-Term Memory (LSTM) networks can also be used for time series forecasting.**

# %% [markdown]
# **The process of time series forecasting typically involves the following steps:**
#
# **Data Preprocessing: Cleaning and transforming the data to handle missing values, outliers, and irregularities. If necessary, the data may be decomposed to extract trend and seasonal components.**
#
# **Model Selection: Choosing an appropriate forecasting model based on the characteristics of the data and the specific problem requirements.**
#
# **Model Training: Using historical data to estimate model parameters and optimize the model's performance.**
#
# **Model Evaluation: Assessing the accuracy of the forecasting model using validation data and appropriate evaluation metrics.**
#
# **Forecasting: Making predictions for future time points using the trained model.**
#
# **Monitoring and Updating: Regularly re-evaluating the forecasting model's performance and updating it with new data to improve accuracy and reliability.**

# %% [markdown]
# <center><h1 style='background-color:#99ccff;padding:10px;font-family:courier'>Adfuller </h1></center>

# %% [markdown]
# **The Augmented Dickey-Fuller (ADF) test, commonly referred to as "Adfuller," is a statistical test used to determine if a time series data is stationary or non-stationary. Stationarity is an essential assumption in many time series models, as it simplifies the underlying patterns and relationships within the data.**

# %%
from statsmodels.tsa.stattools import adfuller  

adfuller_result=adfuller(tempdata,autolag='AIC')

print(f' ADF Statitcs :{adfuller_result[0]}')

print(f' p values :{adfuller_result[1]}')

for key,value in adfuller_result[4].items():
    print('criteria value')
    print(f'{key}{value}')

# %% [markdown]
# <center><h1 style='background-color:#99ccff;padding:10px;font-family:courier'>ARIMA</h1></center>

# %% [markdown]
# **ARIMA stands for Autoregressive Integrated Moving Average. It is a popular time series forecasting method that combines autoregression, differencing, and moving average components to model and predict future values in a time series.**

# %%
from statsmodels.tsa.arima.model import ARIMA

# Assuming you have your time series data in the 'data' variable

# Create and fit the ARIMA model
p, d, q = (1, 1, 1)  # Example values, replace with appropriate values
model = ARIMA(tempdata, order=(p, d, q))
result = model.fit()

# Perform the Augmented Dickey-Fuller test

# Make predictions for the next year ('01/01/1990' to '01/01/1991')
predictions = result.predict(start='2017/01/01', end='2017/04/24')

# Print the predicted values for the next year
print(predictions)

# %%
actual=data['2017/01/01':'2017/04/24']['meantemp'][0:13]

# %%
actual

# %%
from sklearn.metrics import mean_absolute_error
mae=mean_absolute_error(actual[0:13],predictions[0:13])
print(mae)

# %%
data.head()

# %%
data.reset_index(drop=True, inplace=True)

# %% [markdown]
# <center><h1 style='background-color:#99ccff;padding:10px;font-family:courier'>Model Building</h1></center>

# %%
x=data.drop(['meantemp','date'],axis=1)

# %%
x.head()

# %%
y=data['meantemp']

# %% [markdown]
# <center><h1 style='background-color:#99ccff;padding:10px;font-family:courier'>Spilting Data</h1></center>

# %% [markdown]
# **1.Divide the data inti train and test**
#
# **2.test_size keep between 0.20 and 0.30 means 30 percentage of data remain for test and 70 for train**

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30)

# %% [markdown]
# <center><h1 style='background-color:#99ccff;padding:10px;font-family:courier'>Data Scalling</h1></center>

# %% [markdown]
# **Convert the data into the one Scale**
#
# **1.Standard Scalling and min_max scalling are the major scalling method used for scale**

# %%
from sklearn.preprocessing import  StandardScaler

# %%
scaler=StandardScaler()

x_train=pd.DataFrame(scaler.fit_transform(x_train),columns=x_train.columns)
x_test=pd.DataFrame(scaler.fit_transform(x_test),columns=x_test.columns)


x_test.head()

# %%
plt.figure(figsize=(10,5))
plt.title("Features after data scalling")
sns.boxplot(data)
plt.show()

# %% [markdown]
# <center><h1 style='background-color:#99ccff;padding:10px;font-family:courier'>Linear Regression</h1></center>

# %% [markdown]
# **Linear regression is a widely used statistical method for modeling the relationship between a dependent variable and one or more independent variables. It is called "linear" because it assumes that the relationship between the dependent variable and the independent variables can be represented by a linear equation.**
#
# **The primary goal of linear regression is to find the best-fitting straight line (or hyperplane in higher dimensions) that minimizes the difference between the actual values of the dependent variable and the predicted values based on the independent variables. This line is represented by the equation:**
#
# **y = β0 + β1x1 + β2x2 + ... + βn*xn**

# %% [markdown]
# ![](https://editor.analyticsvidhya.com/uploads/375512.jpg)

# %%
from IPython.display import Image, display
import requests

# %%
from sklearn.linear_model import LinearRegression

# %%
from sklearn.metrics import mean_absolute_error

from sklearn.metrics import mean_squared_error

from sklearn.metrics import r2_score

# %%
lr=LinearRegression()

lr.fit(x_train,y_train)

print('score',lr.score(x_test,y_test))

pred=lr.predict(x_test)

# %%
mean_absolute_error(y_test,pred)

# %%
r2_score(y_test,pred)

# %% [markdown]
# <center><h1 style='background-color:#99ccff;padding:10px;font-family:courier'>support Vector Regression</h1></center>

# %% [markdown]
# **Support Vector Regression (SVR) is a variant of the popular Support Vector Machine (SVM) algorithm used for regression tasks. SVR is a powerful and effective method for handling both linear and non-linear regression problems.**
#
# **The main idea behind SVR is to find a hyperplane that best fits the data while trying to minimize the errors (also called residuals) within a certain margin, called the epsilon-tube. The hyperplane is chosen such that the data points are as close to the hyperplane as possible, within the margin.**

# %% [markdown]
# ![](https://static.javatpoint.com/tutorial/machine-learning/images/support-vector-machine-algorithm.png)

# %%
from sklearn.svm import SVR

sr=SVR()

sr.fit(x_train,y_train)

sr.score(x_test,y_test)

# %% [markdown]
# <center><h1 style='background-color:#99ccff;padding:10px;font-family:courier'>Random Forest Regression</h1></center>

# %% [markdown]
# ****Random Forest is a powerful machine learning algorithm used for both regression and classification tasks. It is an ensemble learning method that builds multiple decision trees during the training phase and combines their predictions to improve accuracy and reduce overfitting. The name "Random Forest" comes from the randomness introduced during the training process.****

# %% [markdown]
# ![](https://miro.medium.com/v2/resize:fit:1400/1*ZFuMI_HrI3jt2Wlay73IUQ.png)

# %%
from sklearn.ensemble import RandomForestRegressor
rr=RandomForestRegressor()

rr.fit(x_train,y_train)

rr.score(x_test,y_test)

# %% [markdown]
# <center><h1 style='background-color:#99ccff;padding:10px;font-family:courier'>Kneighbours Regression</h1></center>

# %% [markdown]
# **K-Nearest Neighbors (KNN) is a simple and versatile machine learning algorithm used for both classification and regression tasks. It is a non-parametric algorithm, meaning it does not make assumptions about the underlying data distribution.**

# %% [markdown]
# ![](https://www.researchgate.net/publication/290525297/figure/fig1/AS:768628915961862@1560266822648/Examples-of-classification-of-a-test-vector-using-k-nearest-neighbor-KNN-support.png)

# %%
from sklearn.neighbors import KNeighborsRegressor
knn=KNeighborsRegressor()

knn.fit(x_train,y_train)

knn.score(x_test,y_test)

# %% [markdown]
# <center><h1 style='background-color:#99ccff;padding:10px;font-family:courier'>Decision Tree Regression</h1></center>

# %% [markdown]
# ![](https://static.javatpoint.com/tutorial/machine-learning/images/decision-tree-classification-algorithm.png)

# %% [markdown]
# **Decision Tree Regression, it is a variant of the Decision Tree algorithm used for regression tasks rather than classification tasks. Decision Tree Regression is a powerful and interpretable algorithm that works by recursively partitioning the input feature space into distinct regions and then assigning a constant value (the average of the target values) to each region.**

# %%
from sklearn.tree import DecisionTreeRegressor

dt=DecisionTreeRegressor()

dt.fit(x_train,y_train)

dt.score(x_test,y_test)

# %% [markdown]
# <center><h1 style='background-color:#99ccff;padding:10px;font-family:courier'>Tensorflow</h1></center>

# %% [markdown]
# **TensorFlow is an open-source machine learning library developed by the Google Brain team. It is one of the most popular and powerful frameworks for building and training machine learning models, especially deep learning models. TensorFlow provides a flexible and efficient way to work with numerical computations, particularly those involving multi-dimensional arrays (tensors).**

# %%
import tensorflow  #tensorflow for deep learning

from tensorflow import keras # for making neurons network
from keras import Sequential
from keras.layers import Dense# for adding layes

# %%
model=Sequential()

#relu activation function is used
model.add(Dense(18,activation="relu",input_dim=x_train.shape[1]))
model.add(Dense(9,activation="relu"))
model.add(Dense(4,activation="relu"))
model.add(Dense(1,activation="linear"))# for regression problem output activation is linear

# %%
model.summary()

# %%
model.compile(loss="mean_squared_error",optimizer="Adam",metrics=['accuracy'])

# %%
history=model.fit(x_train,y_train,epochs=100,validation_split=0.2)

# %%
pred=model.predict(x_test)
print(pred)

# %%
r2_score(y_test,pred)

# %%
plt.figure(figsize=(10,5))
i=1
history_list=["loss","accuracy"]
history_list1=["val_loss","val_accuracy"]


for option,val_option in zip(history_list,history_list1):
    plt.subplot(1,2,i)
    sns.lineplot(history.history[option],label=option)
    sns.lineplot(history.history[val_option],label=val_option)
    plt.xlabel("number of Epoch")
    plt.title(f"{option} and {val_option} ")
    i=i+1

# %% [markdown]
# <center><h1 style='background-color:#99ccff;padding:10px;font-family:courier'>Thank You.If You Like Please Upvote</h1></center>
